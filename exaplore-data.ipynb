# %%
import pandas as pd

# %%
data = pd.read_csv('battles.csv')

# %%
data.describe()
# Out:
#        End   Belligerents        Offence        Defence     Casualties  \
# count  0.0      13.000000      13.000000      13.000000      13.000000
# mean   NaN  192165.923077   87620.307692  104545.615385   48075.153846
# std    NaN  173800.499435   72955.387860  106153.108427   37175.941239
# min    NaN      31.000000      14.000000      17.000000    4900.000000
# 25%    NaN   46000.000000   24000.000000   22000.000000   15447.000000
# 50%    NaN  157000.000000   72000.000000   84000.000000   43000.000000
# 75%    NaN  308000.000000  150000.000000  150000.000000   75000.000000
# max    NaN  605000.000000  225000.000000  380000.000000  134000.000000
#
#        Casualties Offence  Casualties Defence           Size
# count           13.000000           13.000000      13.000000
# mean         20968.923077        27106.230769  192165.923077
# std          24996.106198        15685.702769  173800.499435
# min            900.000000         3700.000000      31.000000
# ...
